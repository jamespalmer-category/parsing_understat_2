# %%
import requests
from bs4 import BeautifulSoup
import json
from typing import List

# %%
URL = 'https://understat.com/league/EPL/2021'

# %%
def get_understat_data(url: str) -> List:
    """
    Use bs4 and requests to get the json data that is on the webpage.
    We then need 
    """
    result = requests.get(url)
    src = result.content
    soup = BeautifulSoup(src, 'html.parser')
    json_data = soup.find_all("script")

    Game_Table_Player_data = []
    for json_string in json_data[1:4]:
        """
        Convert the entry into a string, then find the first and last
        quotemarks as this finds our json, then put that into a list.
        """
        
        json_string = str(json_string)
        s_1 = json_string.find('\'')
        s_2 = json_string.rfind('\'')
        json_string = json_string[s_1:s_2 + 1]
        Game_Table_Player_data.append(json_string)

    return Game_Table_Player_data

def load_json(json_list : List) -> dict:
    return {['Game data', 'Team data', 'Player data'][i] : 
           json.loads(json_list[i].encode('ascii').decode('unicode-escape')[1:-1]) for i in range(len(json_list))}

# %%
import pandas as pd

# %%
def game_dict_to_df(game_dict : dict) -> pd.DataFrame:
    """
    Encode/decode the game data to give us a list of dictionaries,
    We then clean up each dictionary and create a dataframe out of
    them all.
    """
    
    game_data = game_dict['Game data']

    df = pd.DataFrame()
    for game in game_data:

        #Rename titles found within our json.
        game['h'] = game['h']['title']
        game['a'] = game['a']['title']
        game['Home goals'] = game['goals']['h']
        game['Away goals'] = game['goals']['a']
        game['xG Home'] = game['xG']['h']
        game['xG Away'] = game['xG']['a']
        game['Probability Home Win'] = game['forecast']['w']
        game['Probability Draw'] = game['forecast']['d']
        game['Probability Away Win'] = game['forecast']['l']

        #delete entries we no longer need
        del game['goals']
        del game['xG']
        del game['forecast']

        #add to main df
        df = pd.concat([df, pd.DataFrame.from_dict([game])], axis = 0, ignore_index = True)

    return df

# %%
def team_dict_to_df(team_dict : dict) -> pd.DataFrame:
    """
    Encode/decode the team data to give us a list of dictionaries,
    We then clean up each dictionary and create a dataframe out of
    them all.
    """
    
    team_data = team_dict['Team data']
    for key in list(team_data.keys()):
        team_data[team_data[key]['title']] = team_data[key]
        del team_data[key]
    for team in list(team_data.keys()):
        team_data[team] = team_data[team]['history']

    
    team_data_dict = {}
    for team in list(team_data.keys()):

        #the dictionaries all represent games, hence we call these games again.
        team_df = pd.DataFrame()
        for game in team_data[team]:

            #Rename titles found within our json.
            game['ppda att'] = game['ppda']['att']
            game['ppda def'] = game['ppda']['def']
            game['ppda allowed att'] = game['ppda_allowed']['att']
            game['ppda allowed def'] = game['ppda_allowed']['def']

            #delete entries we no longer need
            del game['ppda']
            del game['ppda_allowed']

            #add to main df
            team_df = pd.concat([team_df, pd.DataFrame.from_dict([game])], axis = 0)
        team_data_dict[team] = team_df

    return team_data_dict

# %%
for team in list(team_data.keys()):
        team_data[team] = team_data[team]['history']

    df = pd.DataFrame()
    #the dictionaries all represent games, hence we call these games again.
    print(type(team_data))
    for game in team_data:
        print(game.keys())

        #Rename titles found within our json.
        game['ppda att'] = game['ppda']['att']
        game['ppda def'] = game['ppda']['def']
        game['ppda allowed att'] = game['ppda_allowed']['att']
        game['ppda allowed def'] = game['ppda_allowed']['def']

        #delete entries we no longer need
        del game['ppda']
        del game['ppda_allowed']

        #add to main df
        df = pd.concat([df, pd.DataFrame.from_dict([game])], axis = 0)

    return df
# Out:
#   File "<tokenize>", line 4
#     df = pd.DataFrame()
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
EPL_data = get_understat_data(URL)
EPL_gtp_data = load_json(EPL_data)
#EPL_game_data = game_dict_to_df(EPL_gtp_data)
EPL_team_data = team_dict_to_df(EPL_gtp_data)

# %%
EPL_gtp_data['Team data']
# Out:
# {'71': {'id': '71',
#   'title': 'Aston Villa',
#   'history': [{'h_a': 'a',
#     'xG': 1.13718,
#     'xGA': 1.35036,
#     'npxG': 0.376011,
#     'npxGA': 1.35036,
#     'ppda': {'att': 182, 'def': 28},
#     'ppda_allowed': {'att': 303, 'def': 21},
#     'deep': 6,
#     'deep_allowed': 4,
#     'scored': 2,
#     'missed': 3,
#     'xpts': 1.1959,
#     'result': 'l',
#     'date': '2021-08-14 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.974349},
#    {'h_a': 'h',
#     'xG': 1.18426,
#     'xGA': 0.63163,
#     'npxG': 0.423091,
#     'npxGA': 0.63163,
#     'ppda': {'att': 202, 'def': 14},
#     'ppda_allowed': {'att': 150, 'def': 17},
#     'deep': 5,
#     'deep_allowed': 4,
#     'scored': 2,
#     'missed': 0,
#     'xpts': 1.9441,
#     'result': 'w',
#     'date': '2021-08-21 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.20853900000000003},
#    {'h_a': 'h',
#     'xG': 0.431464,
#     'xGA': 1.13312,
#     'npxG': 0.431464,
#     'npxGA': 1.13312,
#     'ppda': {'att': 264, 'def': 20},
#     'ppda_allowed': {'att': 199, 'def': 24},
#     'deep': 2,
#     'deep_allowed': 8,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 0.6785,
#     'result': 'd',
#     'date': '2021-08-28 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.7016559999999998},
#    {'h_a': 'a',
#     'xG': 1.17349,
#     'xGA': 1.22153,
#     'npxG': 1.17349,
#     'npxGA': 1.22153,
#     'ppda': {'att': 306, 'def': 31},
#     'ppda_allowed': {'att': 188, 'def': 19},
#     'deep': 6,
#     'deep_allowed': 3,
#     'scored': 0,
#     'missed': 3,
#     'xpts': 1.3221,
#     'result': 'l',
#     'date': '2021-09-11 16:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.04804000000000008},
#    {'h_a': 'h',
#     'xG': 0.777716,
#     'xGA': 0.755035,
#     'npxG': 0.777716,
#     'npxGA': 0.755035,
#     'ppda': {'att': 148, 'def': 18},
#     'ppda_allowed': {'att': 202, 'def': 17},
#     'deep': 5,
#     'deep_allowed': 2,
#     'scored': 3,
#     'missed': 0,
#     'xpts': 1.3357999999999999,
#     'result': 'w',
#     'date': '2021-09-18 16:30:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.02268099999999995},
#    {'h_a': 'a',
#     'xG': 1.57249,
#     'xGA': 1.9251,
#     'npxG': 1.57249,
#     'npxGA': 1.16393,
#     'ppda': {'att': 207, 'def': 22},
#     'ppda_allowed': {'att': 113, 'def': 18},
#     'deep': 6,
#     'deep_allowed': 5,
#     'scored': 1,
#     'missed': 0,
#     'xpts': 1.1095,
#     'result': 'w',
#     'date': '2021-09-25 11:30:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.40856000000000003},
#    {'h_a': 'a',
#     'xG': 1.07395,
#     'xGA': 1.78187,
#     'npxG': 1.07395,
#     'npxGA': 1.78187,
#     'ppda': {'att': 240, 'def': 33},
#     'ppda_allowed': {'att': 157, 'def': 20},
#     'deep': 11,
#     'deep_allowed': 11,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 0.8379,
#     'result': 'l',
#     'date': '2021-10-03 13:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.7079200000000001},
#    {'h_a': 'h',
#     'xG': 1.21276,
#     'xGA': 2.19633,
#     'npxG': 1.21276,
#     'npxGA': 2.19633,
#     'ppda': {'att': 203, 'def': 16},
#     'ppda_allowed': {'att': 237, 'def': 26},
#     'deep': 7,
#     'deep_allowed': 10,
#     'scored': 2,
#     'missed': 3,
#     'xpts': 0.6525,
#     'result': 'l',
#     'date': '2021-10-16 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.98357},
#    {'h_a': 'a',
#     'xG': 1.41088,
#     'xGA': 3.4984,
#     'npxG': 1.41088,
#     'npxGA': 2.62648,
#     'ppda': {'att': 265, 'def': 20},
#     'ppda_allowed': {'att': 224, 'def': 23},
#     'deep': 7,
#     'deep_allowed': 14,
#     'scored': 1,
#     'missed': 3,
#     'xpts': 0.2518,
#     'result': 'l',
#     'date': '2021-10-22 19:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.2156},
#    {'h_a': 'h',
#     'xG': 0.687551,
#     'xGA': 2.66391,
#     'npxG': 0.687551,
#     'npxGA': 2.66391,
#     'ppda': {'att': 273, 'def': 12},
#     'ppda_allowed': {'att': 158, 'def': 23},
#     'deep': 3,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 4,
#     'xpts': 0.153,
#     'result': 'l',
#     'date': '2021-10-31 16:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.976359},
#    {'h_a': 'a',
#     'xG': 0.536077,
#     'xGA': 0.89818,
#     'npxG': 0.536077,
#     'npxGA': 0.89818,
#     'ppda': {'att': 245, 'def': 23},
#     'ppda_allowed': {'att': 131, 'def': 24},
#     'deep': 13,
#     'deep_allowed': 8,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 0.9174,
#     'result': 'l',
#     'date': '2021-11-05 20:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.36210299999999995},
#    {'h_a': 'h',
#     'xG': 1.06946,
#     'xGA': 0.582787,
#     'npxG': 1.06946,
#     'npxGA': 0.582787,
#     'ppda': {'att': 392, 'def': 22},
#     'ppda_allowed': {'att': 167, 'def': 22},
#     'deep': 6,
#     'deep_allowed': 4,
#     'scored': 2,
#     'missed': 0,
#     'xpts': 1.7925,
#     'result': 'w',
#     'date': '2021-11-20 15:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.486673},
#    {'h_a': 'a',
#     'xG': 0.454305,
#     'xGA': 0.962129,
#     'npxG': 0.454305,
#     'npxGA': 0.962129,
#     'ppda': {'att': 342, 'def': 13},
#     'ppda_allowed': {'att': 181, 'def': 20},
#     'deep': 6,
#     'deep_allowed': 5,
#     'scored': 2,
#     'missed': 1,
#     'xpts': 0.7950999999999999,
#     'result': 'w',
#     'date': '2021-11-27 15:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.507824},
#    {'h_a': 'h',
#     'xG': 0.772083,
#     'xGA': 1.01897,
#     'npxG': 0.772083,
#     'npxGA': 1.01897,
#     'ppda': {'att': 302, 'def': 20},
#     'ppda_allowed': {'att': 192, 'def': 22},
#     'deep': 4,
#     'deep_allowed': 9,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 1.1260999999999999,
#     'result': 'l',
#     'date': '2021-12-01 20:15:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.24688699999999997},
#    {'h_a': 'h',
#     'xG': 1.84818,
#     'xGA': 0.982614,
#     'npxG': 1.84818,
#     'npxGA': 0.982614,
#     'ppda': {'att': 270, 'def': 20},
#     'ppda_allowed': {'att': 159, 'def': 39},
#     'deep': 7,
#     'deep_allowed': 12,
#     'scored': 2,
#     'missed': 1,
#     'xpts': 2.0334,
#     'result': 'w',
#     'date': '2021-12-05 16:30:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.865566},
#    {'h_a': 'a',
#     'xG': 0.140573,
#     'xGA': 2.71181,
#     'npxG': 0.140573,
#     'npxGA': 1.95064,
#     'ppda': {'att': 272, 'def': 11},
#     'ppda_allowed': {'att': 157, 'def': 30},
#     'deep': 4,
#     'deep_allowed': 15,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 0.0507,
#     'result': 'l',
#     'date': '2021-12-11 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.8100669999999999},
#    {'h_a': 'a',
#     'xG': 1.96261,
#     'xGA': 0.502647,
#     'npxG': 1.96261,
#     'npxGA': 0.502647,
#     'ppda': {'att': 283, 'def': 20},
#     'ppda_allowed': {'att': 193, 'def': 22},
#     'deep': 14,
#     'deep_allowed': 5,
#     'scored': 2,
#     'missed': 0,
#     'xpts': 2.5811,
#     'result': 'w',
#     'date': '2021-12-14 19:45:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 1.4599630000000001},
#    {'h_a': 'h',
#     'xG': 0.474029,
#     'xGA': 2.8285,
#     'npxG': 0.474029,
#     'npxGA': 1.30616,
#     'ppda': {'att': 322, 'def': 14},
#     'ppda_allowed': {'att': 277, 'def': 30},
#     'deep': 6,
#     'deep_allowed': 14,
#     'scored': 1,
#     'missed': 3,
#     'xpts': 0.0974,
#     'result': 'l',
#     'date': '2021-12-26 17:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.832131},
#    {'h_a': 'a',
#     'xG': 1.13821,
#     'xGA': 0.501329,
#     'npxG': 1.13821,
#     'npxGA': 0.501329,
#     'ppda': {'att': 220, 'def': 17},
#     'ppda_allowed': {'att': 243, 'def': 30},
#     'deep': 6,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 1.9134000000000002,
#     'result': 'l',
#     'date': '2022-01-02 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': 0.6368809999999999},
#    {'h_a': 'h',
#     'xG': 1.82784,
#     'xGA': 1.35378,
#     'npxG': 1.82784,
#     'npxGA': 1.35378,
#     'ppda': {'att': 273, 'def': 19},
#     'ppda_allowed': {'att': 309, 'def': 29},
#     'deep': 12,
#     'deep_allowed': 4,
#     'scored': 2,
#     'missed': 2,
#     'xpts': 1.7497,
#     'result': 'd',
#     'date': '2022-01-15 17:30:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.4740599999999999},
#    {'h_a': 'a',
#     'xG': 0.860245,
#     'xGA': 1.2384,
#     'npxG': 0.860245,
#     'npxGA': 1.2384,
#     'ppda': {'att': 156, 'def': 32},
#     'ppda_allowed': {'att': 192, 'def': 29},
#     'deep': 5,
#     'deep_allowed': 1,
#     'scored': 1,
#     'missed': 0,
#     'xpts': 1.0054,
#     'result': 'w',
#     'date': '2022-01-22 12:30:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.3781549999999999},
#    {'h_a': 'h',
#     'xG': 1.5013,
#     'xGA': 2.52914,
#     'npxG': 1.5013,
#     'npxGA': 2.52914,
#     'ppda': {'att': 291, 'def': 21},
#     'ppda_allowed': {'att': 148, 'def': 15},
#     'deep': 2,
#     'deep_allowed': 8,
#     'scored': 3,
#     'missed': 3,
#     'xpts': 0.6474,
#     'result': 'd',
#     'date': '2022-02-09 20:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -1.0278399999999999},
#    {'h_a': 'a',
#     'xG': 0.455206,
#     'xGA': 0.527571,
#     'npxG': 0.455206,
#     'npxGA': 0.527571,
#     'ppda': {'att': 103, 'def': 26},
#     'ppda_allowed': {'att': 223, 'def': 33},
#     'deep': 5,
#     'deep_allowed': 2,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 1.192,
#     'result': 'l',
#     'date': '2022-02-13 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.07236500000000001},
#    {'h_a': 'h',
#     'xG': 1.0267,
#     'xGA': 1.82051,
#     'npxG': 1.0267,
#     'npxGA': 1.82051,
#     'ppda': {'att': 225, 'def': 25},
#     'ppda_allowed': {'att': 306, 'def': 14},
#     'deep': 18,
#     'deep_allowed': 4,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 0.715,
#     'result': 'l',
#     'date': '2022-02-19 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.7938100000000001},
#    {'h_a': 'a',
#     'xG': 1.3027,
#     'xGA': 0.627107,
#     'npxG': 1.3027,
#     'npxGA': 0.627107,
#     'ppda': {'att': 334, 'def': 20},
#     'ppda_allowed': {'att': 157, 'def': 25},
#     'deep': 4,
#     'deep_allowed': 5,
#     'scored': 2,
#     'missed': 0,
#     'xpts': 2.0098,
#     'result': 'w',
#     'date': '2022-02-26 15:30:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.675593},
#    {'h_a': 'h',
#     'xG': 2.85379,
#     'xGA': 1.32947,
#     'npxG': 2.85379,
#     'npxGA': 1.32947,
#     'ppda': {'att': 304, 'def': 18},
#     'ppda_allowed': {'att': 181, 'def': 22},
#     'deep': 12,
#     'deep_allowed': 4,
#     'scored': 4,
#     'missed': 0,
#     'xpts': 2.3496,
#     'result': 'w',
#     'date': '2022-03-05 15:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 1.5243200000000001},
#    {'h_a': 'a',
#     'xG': 1.2729,
#     'xGA': 0.194028,
#     'npxG': 1.2729,
#     'npxGA': 0.194028,
#     'ppda': {'att': 237, 'def': 20},
#     'ppda_allowed': {'att': 229, 'def': 35},
#     'deep': 8,
#     'deep_allowed': 1,
#     'scored': 3,
#     'missed': 0,
#     'xpts': 2.2945,
#     'result': 'w',
#     'date': '2022-03-10 19:45:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 1.0788719999999998},
#    {'h_a': 'a',
#     'xG': 1.05391,
#     'xGA': 1.58468,
#     'npxG': 1.05391,
#     'npxGA': 1.58468,
#     'ppda': {'att': 249, 'def': 17},
#     'ppda_allowed': {'att': 260, 'def': 16},
#     'deep': 7,
#     'deep_allowed': 9,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 0.8996999999999999,
#     'result': 'l',
#     'date': '2022-03-13 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.5307700000000002},
#    {'h_a': 'h',
#     'xG': 0.309375,
#     'xGA': 1.14522,
#     'npxG': 0.309375,
#     'npxGA': 1.14522,
#     'ppda': {'att': 302, 'def': 14},
#     'ppda_allowed': {'att': 246, 'def': 18},
#     'deep': 3,
#     'deep_allowed': 11,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 0.5175,
#     'result': 'l',
#     'date': '2022-03-19 12:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.835845},
#    {'h_a': 'a',
#     'xG': 1.91256,
#     'xGA': 1.62151,
#     'npxG': 1.15139,
#     'npxGA': 1.62151,
#     'ppda': {'att': 266, 'def': 22},
#     'ppda_allowed': {'att': 268, 'def': 22},
#     'deep': 8,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 1.5871,
#     'result': 'l',
#     'date': '2022-04-02 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.4701200000000001},
#    {'h_a': 'h',
#     'xG': 1.48712,
#     'xGA': 0.983601,
#     'npxG': 1.48712,
#     'npxGA': 0.983601,
#     'ppda': {'att': 318, 'def': 29},
#     'ppda_allowed': {'att': 212, 'def': 14},
#     'deep': 12,
#     'deep_allowed': 5,
#     'scored': 0,
#     'missed': 4,
#     'xpts': 1.7482,
#     'result': 'l',
#     'date': '2022-04-09 16:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': 0.503519},
#    {'h_a': 'a',
#     'xG': 0.593202,
#     'xGA': 0.235635,
#     'npxG': 0.593202,
#     'npxGA': 0.235635,
#     'ppda': {'att': 332, 'def': 13},
#     'ppda_allowed': {'att': 114, 'def': 25},
#     'deep': 5,
#     'deep_allowed': 4,
#     'scored': 0,
#     'missed': 0,
#     'xpts': 1.6549,
#     'result': 'd',
#     'date': '2022-04-23 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.35756699999999997},
#    {'h_a': 'h',
#     'xG': 2.31192,
#     'xGA': 0.352212,
#     'npxG': 2.31192,
#     'npxGA': 0.352212,
#     'ppda': {'att': 283, 'def': 31},
#     'ppda_allowed': {'att': 199, 'def': 14},
#     'deep': 9,
#     'deep_allowed': 6,
#     'scored': 2,
#     'missed': 0,
#     'xpts': 2.6698,
#     'result': 'w',
#     'date': '2022-04-30 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 1.9597080000000002},
#    {'h_a': 'a',
#     'xG': 1.81256,
#     'xGA': 1.31028,
#     'npxG': 1.81256,
#     'npxGA': 1.31028,
#     'ppda': {'att': 264, 'def': 19},
#     'ppda_allowed': {'att': 259, 'def': 28},
#     'deep': 5,
#     'deep_allowed': 4,
#     'scored': 3,
#     'missed': 1,
#     'xpts': 1.7546,
#     'result': 'w',
#     'date': '2022-05-07 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.5022800000000001},
#    {'h_a': 'h',
#     'xG': 1.44726,
#     'xGA': 1.75417,
#     'npxG': 1.44726,
#     'npxGA': 1.75417,
#     'ppda': {'att': 283, 'def': 14},
#     'ppda_allowed': {'att': 179, 'def': 28},
#     'deep': 3,
#     'deep_allowed': 13,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 1.0753,
#     'result': 'l',
#     'date': '2022-05-10 19:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.30691},
#    {'h_a': 'h',
#     'xG': 0.799443,
#     'xGA': 1.39009,
#     'npxG': 0.799443,
#     'npxGA': 1.39009,
#     'ppda': {'att': 302, 'def': 22},
#     'ppda_allowed': {'att': 246, 'def': 28},
#     'deep': 3,
#     'deep_allowed': 5,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 0.7421,
#     'result': 'd',
#     'date': '2022-05-15 13:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.590647},
#    {'h_a': 'h',
#     'xG': 0.996403,
#     'xGA': 1.63117,
#     'npxG': 0.996403,
#     'npxGA': 0.870001,
#     'ppda': {'att': 99, 'def': 14},
#     'ppda_allowed': {'att': 340, 'def': 17},
#     'deep': 12,
#     'deep_allowed': 5,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 0.7696000000000001,
#     'result': 'd',
#     'date': '2022-05-19 19:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.12640200000000001},
#    {'h_a': 'a',
#     'xG': 0.247841,
#     'xGA': 3.3209,
#     'npxG': 0.247841,
#     'npxGA': 3.3209,
#     'ppda': {'att': 282, 'def': 12},
#     'ppda_allowed': {'att': 124, 'def': 17},
#     'deep': 1,
#     'deep_allowed': 22,
#     'scored': 2,
#     'missed': 3,
#     'xpts': 0.0308,
#     'result': 'l',
#     'date': '2022-05-22 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -3.0730589999999998}]},
#  '72': {'id': '72',
#   'title': 'Everton',
#   'history': [{'h_a': 'h',
#     'xG': 2.38863,
#     'xGA': 0.580601,
#     'npxG': 2.38863,
#     'npxGA': 0.580601,
#     'ppda': {'att': 158, 'def': 23},
#     'ppda_allowed': {'att': 151, 'def': 27},
#     'deep': 4,
#     'deep_allowed': 6,
#     'scored': 3,
#     'missed': 1,
#     'xpts': 2.6311,
#     'result': 'w',
#     'date': '2021-08-14 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 1.8080289999999999},
#    {'h_a': 'a',
#     'xG': 1.85713,
#     'xGA': 0.966093,
#     'npxG': 1.09596,
#     'npxGA': 0.966093,
#     'ppda': {'att': 374, 'def': 22},
#     'ppda_allowed': {'att': 114, 'def': 21},
#     'deep': 6,
#     'deep_allowed': 4,
#     'scored': 2,
#     'missed': 2,
#     'xpts': 2.1241000000000003,
#     'result': 'd',
#     'date': '2021-08-21 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.12986700000000007},
#    {'h_a': 'a',
#     'xG': 1.54868,
#     'xGA': 0.701622,
#     'npxG': 0.787544,
#     'npxGA': 0.701622,
#     'ppda': {'att': 385, 'def': 27},
#     'ppda_allowed': {'att': 140, 'def': 20},
#     'deep': 3,
#     'deep_allowed': 9,
#     'scored': 2,
#     'missed': 0,
#     'xpts': 2.1092999999999997,
#     'result': 'w',
#     'date': '2021-08-28 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.08592200000000005},
#    {'h_a': 'h',
#     'xG': 1.80386,
#     'xGA': 1.82061,
#     'npxG': 1.80386,
#     'npxGA': 1.82061,
#     'ppda': {'att': 191, 'def': 16},
#     'ppda_allowed': {'att': 217, 'def': 20},
#     'deep': 7,
#     'deep_allowed': 4,
#     'scored': 3,
#     'missed': 1,
#     'xpts': 1.3254000000000001,
#     'result': 'w',
#     'date': '2021-09-13 19:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.016750000000000043},
#    {'h_a': 'a',
#     'xG': 0.755035,
#     'xGA': 0.777716,
#     'npxG': 0.755035,
#     'npxGA': 0.777716,
#     'ppda': {'att': 202, 'def': 17},
#     'ppda_allowed': {'att': 148, 'def': 18},
#     'deep': 2,
#     'deep_allowed': 5,
#     'scored': 0,
#     'missed': 3,
#     'xpts': 1.2992,
#     'result': 'l',
#     'date': '2021-09-18 16:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.02268099999999995},
#    {'h_a': 'h',
#     'xG': 2.26681,
#     'xGA': 0.800903,
#     'npxG': 1.50564,
#     'npxGA': 0.800903,
#     'ppda': {'att': 297, 'def': 28},
#     'ppda_allowed': {'att': 210, 'def': 15},
#     'deep': 6,
#     'deep_allowed': 4,
#     'scored': 2,
#     'missed': 0,
#     'xpts': 2.5462,
#     'result': 'w',
#     'date': '2021-09-25 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.7047370000000001},
#    {'h_a': 'a',
#     'xG': 1.32211,
#     'xGA': 1.0496,
#     'npxG': 1.32211,
#     'npxGA': 1.0496,
#     'ppda': {'att': 317, 'def': 16},
#     'ppda_allowed': {'att': 122, 'def': 15},
#     'deep': 2,
#     'deep_allowed': 12,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 1.5787,
#     'result': 'd',
#     'date': '2021-10-02 11:30:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.2725099999999998},
#    {'h_a': 'h',
#     'xG': 0.854165,
#     'xGA': 2.03034,
#     'npxG': 0.854165,
#     'npxGA': 2.03034,
#     'ppda': {'att': 313, 'def': 17},
#     'ppda_allowed': {'att': 147, 'def': 13},
#     'deep': 8,
#     'deep_allowed': 9,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 0.5223,
#     'result': 'l',
#     'date': '2021-10-17 13:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.1761749999999997},
#    {'h_a': 'h',
#     'xG': 1.84089,
#     'xGA': 3.10344,
#     'npxG': 1.84089,
#     'npxGA': 3.10344,
#     'ppda': {'att': 203, 'def': 19},
#     'ppda_allowed': {'att': 188, 'def': 14},
#     'deep': 12,
#     'deep_allowed': 6,
#     'scored': 2,
#     'missed': 5,
#     'xpts': 0.603,
#     'result': 'l',
#     'date': '2021-10-23 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.26255},
#    {'h_a': 'a',
#     'xG': 1.69767,
#     'xGA': 1.69344,
#     'npxG': 1.69767,
#     'npxGA': 1.69344,
#     'ppda': {'att': 377, 'def': 28},
#     'ppda_allowed': {'att': 187, 'def': 22},
#     'deep': 7,
#     'deep_allowed': 6,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 1.3842999999999999,
#     'result': 'l',
#     'date': '2021-11-01 20:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': 0.004229999999999956},
#    {'h_a': 'h',
#     'xG': 0.597906,
#     'xGA': 0.801798,
#     'npxG': 0.597906,
#     'npxGA': 0.801798,
#     'ppda': {'att': 323, 'def': 31},
#     'ppda_allowed': {'att': 217, 'def': 24},
#     'deep': 9,
#     'deep_allowed': 3,
#     'scored': 0,
#     'missed': 0,
#     'xpts': 1.0875,
#     'result': 'd',
#     'date': '2021-11-07 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.20389199999999996},
#    {'h_a': 'a',
#     'xG': 0.266894,
#     'xGA': 2.61302,
#     'npxG': 0.266894,
#     'npxGA': 2.61302,
#     'ppda': {'att': 464, 'def': 8},
#     'ppda_allowed': {'att': 123, 'def': 18},
#     'deep': 3,
#     'deep_allowed': 14,
#     'scored': 0,
#     'missed': 3,
#     'xpts': 0.1081,
#     'result': 'l',
#     'date': '2021-11-21 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -2.346126},
#    {'h_a': 'a',
#     'xG': 0.968075,
#     'xGA': 1.19813,
#     'npxG': 0.968075,
#     'npxGA': 0.436957,
#     'ppda': {'att': 202, 'def': 29},
#     'ppda_allowed': {'att': 251, 'def': 19},
#     'deep': 9,
#     'deep_allowed': 3,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 1.0775,
#     'result': 'l',
#     'date': '2021-11-28 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': 0.531118},
#    {'h_a': 'h',
#     'xG': 0.512263,
#     'xGA': 2.86067,
#     'npxG': 0.512263,
#     'npxGA': 2.86067,
#     'ppda': {'att': 344, 'def': 22},
#     'ppda_allowed': {'att': 116, 'def': 26},
#     'deep': 1,
#     'deep_allowed': 10,
#     'scored': 1,
#     'missed': 4,
#     'xpts': 0.1388,
#     'result': 'l',
#     'date': '2021-12-01 20:15:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -2.348407},
#    {'h_a': 'h',
#     'xG': 1.06108,
#     'xGA': 1.05723,
#     'npxG': 1.06108,
#     'npxGA': 1.05723,
#     'ppda': {'att': 355, 'def': 23},
#     'ppda_allowed': {'att': 162, 'def': 18},
#     'deep': 5,
#     'deep_allowed': 8,
#     'scored': 2,
#     'missed': 1,
#     'xpts': 1.3362999999999998,
#     'result': 'w',
#     'date': '2021-12-06 20:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.003850000000000131},
#    {'h_a': 'a',
#     'xG': 1.27556,
#     'xGA': 2.09864,
#     'npxG': 1.27556,
#     'npxGA': 2.09864,
#     'ppda': {'att': 298, 'def': 31},
#     'ppda_allowed': {'att': 130, 'def': 16},
#     'deep': 5,
#     'deep_allowed': 8,
#     'scored': 1,
#     'missed': 3,
#     'xpts': 0.7711,
#     'result': 'l',
#     'date': '2021-12-12 16:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.82308},
#    {'h_a': 'a',
#     'xG': 0.627528,
#     'xGA': 3.20239,
#     'npxG': 0.627528,
#     'npxGA': 3.20239,
#     'ppda': {'att': 429, 'def': 17},
#     'ppda_allowed': {'att': 76, 'def': 15},
#     'deep': 0,
#     'deep_allowed': 14,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 0.1248,
#     'result': 'd',
#     'date': '2021-12-16 19:45:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -2.574862},
#    {'h_a': 'h',
#     'xG': 1.82698,
#     'xGA': 1.48397,
#     'npxG': 1.06581,
#     'npxGA': 1.48397,
#     'ppda': {'att': 215, 'def': 19},
#     'ppda_allowed': {'att': 186, 'def': 23},
#     'deep': 5,
#     'deep_allowed': 8,
#     'scored': 2,
#     'missed': 3,
#     'xpts': 1.6211,
#     'result': 'l',
#     'date': '2022-01-02 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.4181600000000001},
#    {'h_a': 'a',
#     'xG': 0.541027,
#     'xGA': 1.00153,
#     'npxG': 0.541027,
#     'npxGA': 1.00153,
#     'ppda': {'att': 139, 'def': 26},
#     'ppda_allowed': {'att': 242, 'def': 20},
#     'deep': 7,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 0.8229,
#     'result': 'l',
#     'date': '2022-01-15 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.460503},
#    {'h_a': 'h',
#     'xG': 1.2384,
#     'xGA': 0.860245,
#     'npxG': 1.2384,
#     'npxGA': 0.860245,
#     'ppda': {'att': 192, 'def': 29},
#     'ppda_allowed': {'att': 156, 'def': 32},
#     'deep': 1,
#     'deep_allowed': 5,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 1.6768,
#     'result': 'l',
#     'date': '2022-01-22 12:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': 0.3781549999999999},
#    {'h_a': 'a',
#     'xG': 0.823607,
#     'xGA': 2.68732,
#     'npxG': 0.823607,
#     'npxGA': 2.68732,
#     'ppda': {'att': 133, 'def': 25},
#     'ppda_allowed': {'att': 271, 'def': 39},
#     'deep': 1,
#     'deep_allowed': 3,
#     'scored': 1,
#     'missed': 3,
#     'xpts': 0.2541,
#     'result': 'l',
#     'date': '2022-02-08 19:45:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.8637130000000002},
#    {'h_a': 'h',
#     'xG': 2.58561,
#     'xGA': 0.242668,
#     'npxG': 2.58561,
#     'npxGA': 0.242668,
#     'ppda': {'att': 301, 'def': 27},
#     'ppda_allowed': {'att': 139, 'def': 23},
#     'deep': 10,
#     'deep_allowed': 4,
#     'scored': 3,
#     'missed': 0,
#     'xpts': 2.8679,
#     'result': 'w',
#     'date': '2022-02-12 15:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 2.342942},
#    {'h_a': 'a',
#     'xG': 0.19991,
#     'xGA': 2.72851,
#     'npxG': 0.19991,
#     'npxGA': 2.72851,
#     'ppda': {'att': 267, 'def': 27},
#     'ppda_allowed': {'att': 153, 'def': 26},
#     'deep': 8,
#     'deep_allowed': 9,
#     'scored': 0,
#     'missed': 2,
#     'xpts': 0.0673,
#     'result': 'l',
#     'date': '2022-02-19 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -2.5286},
#    {'h_a': 'h',
#     'xG': 0.770819,
#     'xGA': 1.93422,
#     'npxG': 0.770819,
#     'npxGA': 1.93422,
#     'ppda': {'att': 355, 'def': 22},
#     'ppda_allowed': {'att': 174, 'def': 29},
#     'deep': 6,
#     'deep_allowed': 10,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 0.4503,
#     'result': 'l',
#     'date': '2022-02-26 17:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.163401},
#    {'h_a': 'a',
#     'xG': 0.208263,
#     'xGA': 3.24279,
#     'npxG': 0.208263,
#     'npxGA': 3.24279,
#     'ppda': {'att': 450, 'def': 21},
#     'ppda_allowed': {'att': 278, 'def': 28},
#     'deep': 2,
#     'deep_allowed': 13,
#     'scored': 0,
#     'missed': 5,
#     'xpts': 0.0415,
#     'result': 'l',
#     'date': '2022-03-07 20:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -3.0345269999999998},
#    {'h_a': 'h',
#     'xG': 0.397268,
#     'xGA': 0.712135,
#     'npxG': 0.397268,
#     'npxGA': 0.712135,
#     'ppda': {'att': 366, 'def': 21},
#     'ppda_allowed': {'att': 219, 'def': 24},
#     'deep': 4,
#     'deep_allowed': 3,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 0.9760000000000001,
#     'result': 'l',
#     'date': '2022-03-13 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.31486699999999995},
#    {'h_a': 'h',
#     'xG': 0.708809,
#     'xGA': 0.75803,
#     'npxG': 0.708809,
#     'npxGA': 0.75803,
#     'ppda': {'att': 234, 'def': 22},
#     'ppda_allowed': {'att': 122, 'def': 17},
#     'deep': 4,
#     'deep_allowed': 10,
#     'scored': 1,
#     'missed': 0,
#     'xpts': 1.2871000000000001,
#     'result': 'w',
#     'date': '2022-03-17 19:45:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.04922099999999996},
#    {'h_a': 'a',
#     'xG': 0.657846,
#     'xGA': 1.49657,
#     'npxG': 0.657846,
#     'npxGA': 1.49657,
#     'ppda': {'att': 323, 'def': 13},
#     'ppda_allowed': {'att': 207, 'def': 7},
#     'deep': 9,
#     'deep_allowed': 6,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 0.6297,
#     'result': 'l',
#     'date': '2022-04-03 13:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.8387239999999999},
#    {'h_a': 'a',
#     'xG': 2.31574,
#     'xGA': 2.24439,
#     'npxG': 0.793435,
#     'npxGA': 2.24439,
#     'ppda': {'att': 126, 'def': 22},
#     'ppda_allowed': {'att': 84, 'def': 22},
#     'deep': 6,
#     'deep_allowed': 12,
#     'scored': 2,
#     'missed': 3,
#     'xpts': 1.4121000000000001,
#     'result': 'l',
#     'date': '2022-04-06 18:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.450955},
#    {'h_a': 'h',
#     'xG': 0.357295,
#     'xGA': 0.762357,
#     'npxG': 0.357295,
#     'npxGA': 0.762357,
#     'ppda': {'att': 299, 'def': 16},
#     'ppda_allowed': {'att': 144, 'def': 24},
#     'deep': 1,
#     'deep_allowed': 15,
#     'scored': 1,
#     'missed': 0,
#     'xpts': 0.8654999999999999,
#     'result': 'w',
#     'date': '2022-04-09 11:30:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.405062},
#    {'h_a': 'h',
#     'xG': 1.68819,
#     'xGA': 0.786333,
#     'npxG': 1.68819,
#     'npxGA': 0.786333,
#     'ppda': {'att': 362, 'def': 23},
#     'ppda_allowed': {'att': 169, 'def': 23},
#     'deep': 6,
#     'deep_allowed': 12,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 2.1176000000000004,
#     'result': 'd',
#     'date': '2022-04-20 18:45:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.9018570000000001},
#    {'h_a': 'a',
#     'xG': 0.424961,
#     'xGA': 1.70397,
#     'npxG': 0.424961,
#     'npxGA': 1.70397,
#     'ppda': {'att': 379, 'def': 13},
#     'ppda_allowed': {'att': 72, 'def': 20},
#     'deep': 2,
#     'deep_allowed': 15,
#     'scored': 0,
#     'missed': 2,
#     'xpts': 0.39559999999999995,
#     'result': 'l',
#     'date': '2022-04-24 15:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.279009},
#    {'h_a': 'h',
#     'xG': 1.11712,
#     'xGA': 1.21141,
#     'npxG': 1.11712,
#     'npxGA': 1.21141,
#     'ppda': {'att': 377, 'def': 22},
#     'ppda_allowed': {'att': 71, 'def': 16},
#     'deep': 5,
#     'deep_allowed': 11,
#     'scored': 1,
#     'missed': 0,
#     'xpts': 1.2618,
#     'result': 'w',
#     'date': '2022-05-01 13:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.09429000000000021},
#    {'h_a': 'a',
#     'xG': 1.55635,
#     'xGA': 1.47479,
#     'npxG': 1.55635,
#     'npxGA': 1.47479,
#     'ppda': {'att': 338, 'def': 15},
#     'ppda_allowed': {'att': 136, 'def': 18},
#     'deep': 4,
#     'deep_allowed': 10,
#     'scored': 2,
#     'missed': 1,
#     'xpts': 1.4396,
#     'result': 'w',
#     'date': '2022-05-08 13:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.08155999999999985},
#    {'h_a': 'a',
#     'xG': 0.812193,
#     'xGA': 0.232236,
#     'npxG': 0.812193,
#     'npxGA': 0.232236,
#     'ppda': {'att': 291, 'def': 28},
#     'ppda_allowed': {'att': 261, 'def': 14},
#     'deep': 6,
#     'deep_allowed': 3,
#     'scored': 0,
#     'missed': 0,
#     'xpts': 1.8954,
#     'result': 'd',
#     'date': '2022-05-11 18:45:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.5799570000000001},
#    {'h_a': 'h',
#     'xG': 2.69589,
#     'xGA': 1.81626,
#     'npxG': 1.93472,
#     'npxGA': 1.81626,
#     'ppda': {'att': 303, 'def': 11},
#     'ppda_allowed': {'att': 82, 'def': 14},
#     'deep': 5,
#     'deep_allowed': 7,
#     'scored': 2,
#     'missed': 3,
#     'xpts': 2.0349000000000004,
#     'result': 'l',
#     'date': '2022-05-15 15:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': 0.11846000000000001},
#    {'h_a': 'h',
#     'xG': 0.813157,
#     'xGA': 1.6023,
#     'npxG': 0.813157,
#     'npxGA': 1.6023,
#     'ppda': {'att': 271, 'def': 20},
#     'ppda_allowed': {'att': 121, 'def': 17},
#     'deep': 4,
#     'deep_allowed': 3,
#     'scored': 3,
#     'missed': 2,
#     'xpts': 0.6057,
#     'result': 'w',
#     'date': '2022-05-19 18:45:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.789143},
#    {'h_a': 'a',
#     'xG': 1.08601,
#     'xGA': 4.35597,
#     'npxG': 1.08601,
#     'npxGA': 3.5948,
#     'ppda': {'att': 298, 'def': 6},
#     'ppda_allowed': {'att': 96, 'def': 20},
#     'deep': 5,
#     'deep_allowed': 11,
#     'scored': 1,
#     'missed': 5,
#     'xpts': 0.0474,
#     'result': 'l',
#     'date': '2022-05-22 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -2.5087900000000003}]},
#  '74': {'id': '74',
#   'title': 'Southampton',
#   'history': [{'h_a': 'a',
#     'xG': 0.580601,
#     'xGA': 2.38863,
#     'npxG': 0.580601,
#     'npxGA': 2.38863,
#     'ppda': {'att': 151, 'def': 27},
#     'ppda_allowed': {'att': 158, 'def': 23},
#     'deep': 6,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 3,
#     'xpts': 0.2455,
#     'result': 'l',
#     'date': '2021-08-14 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.8080289999999999},
#    {'h_a': 'h',
#     'xG': 0.587526,
#     'xGA': 2.26173,
#     'npxG': 0.587526,
#     'npxGA': 2.26173,
#     'ppda': {'att': 275, 'def': 31},
#     'ppda_allowed': {'att': 136, 'def': 15},
#     'deep': 3,
#     'deep_allowed': 11,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 0.27690000000000003,
#     'result': 'd',
#     'date': '2021-08-22 13:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -1.674204},
#    {'h_a': 'a',
#     'xG': 3.46036,
#     'xGA': 1.19077,
#     'npxG': 2.69919,
#     'npxGA': 1.19077,
#     'ppda': {'att': 131, 'def': 17},
#     'ppda_allowed': {'att': 234, 'def': 24},
#     'deep': 10,
#     'deep_allowed': 6,
#     'scored': 2,
#     'missed': 2,
#     'xpts': 2.7954999999999997,
#     'result': 'd',
#     'date': '2021-08-28 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 1.50842},
#    {'h_a': 'h',
#     'xG': 0.692135,
#     'xGA': 0.725407,
#     'npxG': 0.692135,
#     'npxGA': 0.725407,
#     'ppda': {'att': 287, 'def': 12},
#     'ppda_allowed': {'att': 231, 'def': 30},
#     'deep': 4,
#     'deep_allowed': 1,
#     'scored': 0,
#     'missed': 0,
#     'xpts': 1.2896999999999998,
#     'result': 'd',
#     'date': '2021-09-11 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.03327200000000008},
#    {'h_a': 'a',
#     'xG': 0.490923,
#     'xGA': 1.22451,
#     'npxG': 0.490923,
#     'npxGA': 1.22451,
#     'ppda': {'att': 363, 'def': 22},
#     'ppda_allowed': {'att': 173, 'def': 15},
#     'deep': 6,
#     'deep_allowed': 6,
#     'scored': 0,
#     'missed': 0,
#     'xpts': 0.7269000000000001,
#     'result': 'd',
#     'date': '2021-09-18 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.733587},
#    {'h_a': 'h',
#     'xG': 0.909342,
#     'xGA': 0.909833,
#     'npxG': 0.909342,
#     'npxGA': 0.909833,
#     'ppda': {'att': 184, 'def': 22},
#     'ppda_allowed': {'att': 259, 'def': 8},
#     'deep': 7,
#     'deep_allowed': 3,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 1.3033,
#     'result': 'l',
#     'date': '2021-09-26 13:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.0004910000000000192},
#    {'h_a': 'a',
#     'xG': 1.52634,
#     'xGA': 3.79243,
#     'npxG': 0.765173,
#     'npxGA': 3.79243,
#     'ppda': {'att': 341, 'def': 36},
#     'ppda_allowed': {'att': 175, 'def': 24},
#     'deep': 4,
#     'deep_allowed': 12,
#     'scored': 1,
#     'missed': 3,
#     'xpts': 0.1839,
#     'result': 'l',
#     'date': '2021-10-02 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -3.027257},
#    {'h_a': 'h',
#     'xG': 1.83082,
#     'xGA': 0.446173,
#     'npxG': 1.83082,
#     'npxGA': 0.446173,
#     'ppda': {'att': 260, 'def': 34},
#     'ppda_allowed': {'att': 174, 'def': 31},
#     'deep': 4,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 0,
#     'xpts': 2.4654000000000003,
#     'result': 'w',
#     'date': '2021-10-16 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 1.384647},
#    {'h_a': 'h',
#     'xG': 1.42567,
#     'xGA': 0.673195,
#     'npxG': 1.42567,
#     'npxGA': 0.673195,
#     'ppda': {'att': 95, 'def': 15},
#     'ppda_allowed': {'att': 214, 'def': 22},
#     'deep': 6,
#     'deep_allowed': 4,
#     'scored': 2,
#     'missed': 2,
#     'xpts': 2.0092,
#     'result': 'd',
#     'date': '2021-10-23 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.752475},
#    {'h_a': 'a',
#     'xG': 1.90757,
#     'xGA': 0.852556,
#     'npxG': 1.90757,
#     'npxGA': 0.852556,
#     'ppda': {'att': 134, 'def': 19},
#     'ppda_allowed': {'att': 261, 'def': 26},
#     'deep': 11,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 0,
#     'xpts': 2.2118,
#     'result': 'w',
#     'date': '2021-10-30 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 1.055014},
#    {'h_a': 'h',
#     'xG': 0.89818,
#     'xGA': 0.536077,
#     'npxG': 0.89818,
#     'npxGA': 0.536077,
#     'ppda': {'att': 131, 'def': 24},
#     'ppda_allowed': {'att': 245, 'def': 23},
#     'deep': 8,
#     'deep_allowed': 13,
#     'scored': 1,
#     'missed': 0,
#     'xpts': 1.7231999999999998,
#     'result': 'w',
#     'date': '2021-11-05 20:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.36210299999999995},
#    {'h_a': 'a',
#     'xG': 1.13118,
#     'xGA': 0.43778,
#     'npxG': 1.13118,
#     'npxGA': 0.43778,
#     'ppda': {'att': 132, 'def': 17},
#     'ppda_allowed': {'att': 301, 'def': 28},
#     'deep': 9,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 1.9398,
#     'result': 'l',
#     'date': '2021-11-20 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': 0.6934},
#    {'h_a': 'a',
#     'xG': 0.966132,
#     'xGA': 3.07278,
#     'npxG': 0.966132,
#     'npxGA': 3.07278,
#     'ppda': {'att': 350, 'def': 23},
#     'ppda_allowed': {'att': 173, 'def': 18},
#     'deep': 2,
#     'deep_allowed': 14,
#     'scored': 0,
#     'missed': 4,
#     'xpts': 0.2162,
#     'result': 'l',
#     'date': '2021-11-27 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -2.106648},
#    {'h_a': 'h',
#     'xG': 1.91169,
#     'xGA': 1.4401,
#     'npxG': 1.91169,
#     'npxGA': 1.4401,
#     'ppda': {'att': 262, 'def': 26},
#     'ppda_allowed': {'att': 159, 'def': 18},
#     'deep': 10,
#     'deep_allowed': 5,
#     'scored': 2,
#     'missed': 2,
#     'xpts': 1.748,
#     'result': 'd',
#     'date': '2021-12-01 19:30:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.47158999999999995},
#    {'h_a': 'h',
#     'xG': 1.34236,
#     'xGA': 1.4872,
#     'npxG': 1.34236,
#     'npxGA': 1.4872,
#     'ppda': {'att': 199, 'def': 23},
#     'ppda_allowed': {'att': 106, 'def': 25},
#     'deep': 8,
#     'deep_allowed': 6,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 1.2105,
#     'result': 'd',
#     'date': '2021-12-04 15:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.14484000000000008},
#    {'h_a': 'a',
#     'xG': 0.502215,
#     'xGA': 2.08429,
#     'npxG': 0.502215,
#     'npxGA': 2.08429,
#     'ppda': {'att': 300, 'def': 15},
#     'ppda_allowed': {'att': 171, 'def': 8},
#     'deep': 2,
#     'deep_allowed': 7,
#     'scored': 0,
#     'missed': 3,
#     'xpts': 0.31889999999999996,
#     'result': 'l',
#     'date': '2021-12-11 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.5820750000000001},
#    {'h_a': 'a',
#     'xG': 0.625183,
#     'xGA': 1.49244,
#     'npxG': 0.625183,
#     'npxGA': 1.49244,
#     'ppda': {'att': 248, 'def': 39},
#     'ppda_allowed': {'att': 128, 'def': 24},
#     'deep': 2,
#     'deep_allowed': 4,
#     'scored': 2,
#     'missed': 2,
#     'xpts': 0.641,
#     'result': 'd',
#     'date': '2021-12-15 19:30:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.867257},
#    {'h_a': 'a',
#     'xG': 1.35643,
#     'xGA': 1.53745,
#     'npxG': 0.595257,
#     'npxGA': 1.53745,
#     'ppda': {'att': 206, 'def': 22},
#     'ppda_allowed': {'att': 172, 'def': 18},
#     'deep': 2,
#     'deep_allowed': 10,
#     'scored': 3,
#     'missed': 2,
#     'xpts': 1.1727,
#     'result': 'w',
#     'date': '2021-12-26 15:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.942193},
#    {'h_a': 'h',
#     'xG': 0.353043,
#     'xGA': 2.80917,
#     'npxG': 0.353043,
#     'npxGA': 2.048,
#     'ppda': {'att': 228, 'def': 28},
#     'ppda_allowed': {'att': 107, 'def': 14},
#     'deep': 0,
#     'deep_allowed': 10,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 0.1031,
#     'result': 'd',
#     'date': '2021-12-28 15:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -1.694957},
#    {'h_a': 'h',
#     'xG': 1.59306,
#     'xGA': 0.621466,
#     'npxG': 1.59306,
#     'npxGA': 0.621466,
#     'ppda': {'att': 223, 'def': 26},
#     'ppda_allowed': {'att': 176, 'def': 18},
#     'deep': 1,
#     'deep_allowed': 3,
#     'scored': 4,
#     'missed': 1,
#     'xpts': 2.1879,
#     'result': 'w',
#     'date': '2022-01-11 21:45:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.971594},
#    {'h_a': 'a',
#     'xG': 0.91728,
#     'xGA': 2.29917,
#     'npxG': 0.91728,
#     'npxGA': 1.538,
#     'ppda': {'att': 167, 'def': 13},
#     'ppda_allowed': {'att': 237, 'def': 25},
#     'deep': 8,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 3,
#     'xpts': 0.3762,
#     'result': 'l',
#     'date': '2022-01-15 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.62072},
#    {'h_a': 'h',
#     'xG': 1.00222,
#     'xGA': 1.62907,
#     'npxG': 1.00222,
#     'npxGA': 1.62907,
#     'ppda': {'att': 356, 'def': 17},
#     'ppda_allowed': {'att': 147, 'def': 30},
#     'deep': 1,
#     'deep_allowed': 17,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 0.8467,
#     'result': 'd',
#     'date': '2022-01-22 17:30:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.6268499999999999},
#    {'h_a': 'a',
#     'xG': 1.73293,
#     'xGA': 1.74286,
#     'npxG': 1.73293,
#     'npxGA': 1.74286,
#     'ppda': {'att': 237, 'def': 25},
#     'ppda_allowed': {'att': 206, 'def': 19},
#     'deep': 7,
#     'deep_allowed': 4,
#     'scored': 3,
#     'missed': 2,
#     'xpts': 1.3425000000000002,
#     'result': 'w',
#     'date': '2022-02-09 19:45:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.009929999999999994},
#    {'h_a': 'a',
#     'xG': 0.677386,
#     'xGA': 2.99207,
#     'npxG': 0.677386,
#     'npxGA': 2.99207,
#     'ppda': {'att': 263, 'def': 29},
#     'ppda_allowed': {'att': 244, 'def': 23},
#     'deep': 7,
#     'deep_allowed': 8,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 0.1409,
#     'result': 'd',
#     'date': '2022-02-12 12:30:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -2.3146839999999997},
#    {'h_a': 'h',
#     'xG': 2.72851,
#     'xGA': 0.19991,
#     'npxG': 2.72851,
#     'npxGA': 0.19991,
#     'ppda': {'att': 153, 'def': 26},
#     'ppda_allowed': {'att': 267, 'def': 27},
#     'deep': 9,
#     'deep_allowed': 8,
#     'scored': 2,
#     'missed': 0,
#     'xpts': 2.8855000000000004,
#     'result': 'w',
#     'date': '2022-02-19 15:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 2.5286},
#    {'h_a': 'h',
#     'xG': 3.08863,
#     'xGA': 0.424877,
#     'npxG': 3.08863,
#     'npxGA': 0.424877,
#     'ppda': {'att': 197, 'def': 21},
#     'ppda_allowed': {'att': 220, 'def': 14},
#     'deep': 9,
#     'deep_allowed': 4,
#     'scored': 2,
#     'missed': 0,
#     'xpts': 2.8648,
#     'result': 'w',
#     'date': '2022-02-25 20:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 2.6637530000000003},
#    {'h_a': 'a',
#     'xG': 1.32947,
#     'xGA': 2.85379,
#     'npxG': 1.32947,
#     'npxGA': 2.85379,
#     'ppda': {'att': 181, 'def': 22},
#     'ppda_allowed': {'att': 304, 'def': 18},
#     'deep': 4,
#     'deep_allowed': 12,
#     'scored': 0,
#     'missed': 4,
#     'xpts': 0.48929999999999996,
#     'result': 'l',
#     'date': '2022-03-05 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.5243200000000001},
#    {'h_a': 'h',
#     'xG': 1.79835,
#     'xGA': 0.812233,
#     'npxG': 1.79835,
#     'npxGA': 0.812233,
#     'ppda': {'att': 146, 'def': 18},
#     'ppda_allowed': {'att': 322, 'def': 22},
#     'deep': 8,
#     'deep_allowed': 5,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 2.1947,
#     'result': 'l',
#     'date': '2022-03-10 19:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': 0.9861169999999999},
#    {'h_a': 'h',
#     'xG': 1.25696,
#     'xGA': 1.29385,
#     'npxG': 1.25696,
#     'npxGA': 1.29385,
#     'ppda': {'att': 118, 'def': 18},
#     'ppda_allowed': {'att': 235, 'def': 17},
#     'deep': 5,
#     'deep_allowed': 5,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 1.3351,
#     'result': 'l',
#     'date': '2022-03-13 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.03688999999999987},
#    {'h_a': 'a',
#     'xG': 2.06387,
#     'xGA': 1.50715,
#     'npxG': 2.06387,
#     'npxGA': 1.50715,
#     'ppda': {'att': 258, 'def': 13},
#     'ppda_allowed': {'att': 136, 'def': 21},
#     'deep': 11,
#     'deep_allowed': 18,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 1.8314000000000001,
#     'result': 'd',
#     'date': '2022-04-02 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.5567200000000001},
#    {'h_a': 'h',
#     'xG': 0.564726,
#     'xGA': 4.39683,
#     'npxG': 0.564726,
#     'npxGA': 4.39683,
#     'ppda': {'att': 416, 'def': 17},
#     'ppda_allowed': {'att': 149, 'def': 24},
#     'deep': 2,
#     'deep_allowed': 14,
#     'scored': 0,
#     'missed': 6,
#     'xpts': 0.018,
#     'result': 'l',
#     'date': '2022-04-09 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -3.8321039999999997},
#    {'h_a': 'h',
#     'xG': 1.04007,
#     'xGA': 1.35002,
#     'npxG': 1.04007,
#     'npxGA': 1.35002,
#     'ppda': {'att': 302, 'def': 12},
#     'ppda_allowed': {'att': 84, 'def': 11},
#     'deep': 4,
#     'deep_allowed': 12,
#     'scored': 1,
#     'missed': 0,
#     'xpts': 1.1366,
#     'result': 'w',
#     'date': '2022-04-16 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.30994999999999995},
#    {'h_a': 'a',
#     'xG': 1.31837,
#     'xGA': 2.14743,
#     'npxG': 1.31837,
#     'npxGA': 2.14743,
#     'ppda': {'att': 168, 'def': 17},
#     'ppda_allowed': {'att': 234, 'def': 15},
#     'deep': 4,
#     'deep_allowed': 4,
#     'scored': 0,
#     'missed': 2,
#     'xpts': 0.7872,
#     'result': 'l',
#     'date': '2022-04-21 18:45:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.8290599999999999},
#    {'h_a': 'a',
#     'xG': 0.926764,
#     'xGA': 1.87343,
#     'npxG': 0.926764,
#     'npxGA': 1.87343,
#     'ppda': {'att': 130, 'def': 16},
#     'ppda_allowed': {'att': 150, 'def': 22},
#     'deep': 7,
#     'deep_allowed': 5,
#     'scored': 2,
#     'missed': 2,
#     'xpts': 0.525,
#     'result': 'd',
#     'date': '2022-04-24 13:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.9466659999999999},
#    {'h_a': 'h',
#     'xG': 0.650256,
#     'xGA': 0.756217,
#     'npxG': 0.650256,
#     'npxGA': 0.756217,
#     'ppda': {'att': 320, 'def': 30},
#     'ppda_allowed': {'att': 149, 'def': 14},
#     'deep': 5,
#     'deep_allowed': 5,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 1.2252999999999998,
#     'result': 'l',
#     'date': '2022-04-30 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.10596100000000008},
#    {'h_a': 'a',
#     'xG': 0.988574,
#     'xGA': 3.68223,
#     'npxG': 0.988574,
#     'npxGA': 3.68223,
#     'ppda': {'att': 149, 'def': 16},
#     'ppda_allowed': {'att': 203, 'def': 24},
#     'deep': 5,
#     'deep_allowed': 11,
#     'scored': 0,
#     'missed': 3,
#     'xpts': 0.1444,
#     'result': 'l',
#     'date': '2022-05-07 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -2.6936560000000003},
#    {'h_a': 'h',
#     'xG': 0.121506,
#     'xGA': 1.19178,
#     'npxG': 0.121506,
#     'npxGA': 1.19178,
#     'ppda': {'att': 380, 'def': 20},
#     'ppda_allowed': {'att': 155, 'def': 20},
#     'deep': 3,
#     'deep_allowed': 12,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 0.39559999999999995,
#     'result': 'l',
#     'date': '2022-05-17 18:45:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.070274},
#    {'h_a': 'a',
#     'xG': 1.05141,
# ...
#     'npxGA': 1.64248,
#     'ppda': {'att': 239, 'def': 33},
#     'ppda_allowed': {'att': 277, 'def': 22},
#     'deep': 3,
#     'deep_allowed': 8,
#     'scored': 1,
#     'missed': 5,
#     'xpts': 0.5492,
#     'result': 'l',
#     'date': '2021-08-14 11:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.074138},
#    {'h_a': 'h',
#     'xG': 0.966093,
#     'xGA': 1.85713,
#     'npxG': 0.966093,
#     'npxGA': 1.09596,
#     'ppda': {'att': 114, 'def': 21},
#     'ppda_allowed': {'att': 374, 'def': 22},
#     'deep': 4,
#     'deep_allowed': 6,
#     'scored': 2,
#     'missed': 2,
#     'xpts': 0.6439,
#     'result': 'd',
#     'date': '2021-08-21 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.12986700000000007},
#    {'h_a': 'a',
#     'xG': 1.52078,
#     'xGA': 1.71102,
#     'npxG': 1.52078,
#     'npxGA': 1.71102,
#     'ppda': {'att': 122, 'def': 15},
#     'ppda_allowed': {'att': 346, 'def': 24},
#     'deep': 9,
#     'deep_allowed': 2,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 1.1537,
#     'result': 'd',
#     'date': '2021-08-29 13:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.19023999999999996},
#    {'h_a': 'h',
#     'xG': 0.652514,
#     'xGA': 4.4016,
#     'npxG': 0.652514,
#     'npxGA': 4.4016,
#     'ppda': {'att': 304, 'def': 8},
#     'ppda_allowed': {'att': 252, 'def': 15},
#     'deep': 8,
#     'deep_allowed': 15,
#     'scored': 0,
#     'missed': 3,
#     'xpts': 0.0453,
#     'result': 'l',
#     'date': '2021-09-12 15:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -3.749086},
#    {'h_a': 'a',
#     'xG': 1.42995,
#     'xGA': 1.17668,
#     'npxG': 1.42995,
#     'npxGA': 1.17668,
#     'ppda': {'att': 144, 'def': 26},
#     'ppda_allowed': {'att': 338, 'def': 20},
#     'deep': 13,
#     'deep_allowed': 10,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 1.5584000000000002,
#     'result': 'd',
#     'date': '2021-09-17 19:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.2532700000000001},
#    {'h_a': 'h',
#     'xG': 1.1967,
#     'xGA': 1.98962,
#     'npxG': 1.1967,
#     'npxGA': 1.98962,
#     'ppda': {'att': 191, 'def': 14},
#     'ppda_allowed': {'att': 244, 'def': 12},
#     'deep': 8,
#     'deep_allowed': 5,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 0.8236999999999999,
#     'result': 'l',
#     'date': '2021-09-25 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.7929199999999998},
#    {'h_a': 'h',
#     'xG': 1.57388,
#     'xGA': 0.192794,
#     'npxG': 1.57388,
#     'npxGA': 0.192794,
#     'ppda': {'att': 108, 'def': 16},
#     'ppda_allowed': {'att': 291, 'def': 21},
#     'deep': 9,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 0,
#     'xpts': 2.5128000000000004,
#     'result': 'w',
#     'date': '2021-10-02 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 1.381086},
#    {'h_a': 'a',
#     'xG': 0.446173,
#     'xGA': 1.83082,
#     'npxG': 0.446173,
#     'npxGA': 1.83082,
#     'ppda': {'att': 174, 'def': 31},
#     'ppda_allowed': {'att': 260, 'def': 34},
#     'deep': 4,
#     'deep_allowed': 4,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 0.348,
#     'result': 'l',
#     'date': '2021-10-16 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.384647},
#    {'h_a': 'h',
#     'xG': 1.71313,
#     'xGA': 0.858644,
#     'npxG': 0.951964,
#     'npxGA': 0.858644,
#     'ppda': {'att': 144, 'def': 40},
#     'ppda_allowed': {'att': 280, 'def': 18},
#     'deep': 4,
#     'deep_allowed': 2,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 2.0893,
#     'result': 'd',
#     'date': '2021-10-23 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.09332000000000007},
#    {'h_a': 'a',
#     'xG': 1.16855,
#     'xGA': 0.661887,
#     'npxG': 1.16855,
#     'npxGA': 0.661887,
#     'ppda': {'att': 150, 'def': 35},
#     'ppda_allowed': {'att': 192, 'def': 22},
#     'deep': 5,
#     'deep_allowed': 2,
#     'scored': 2,
#     'missed': 1,
#     'xpts': 1.8229,
#     'result': 'w',
#     'date': '2021-10-31 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.506663},
#    {'h_a': 'h',
#     'xG': 1.96551,
#     'xGA': 0.795292,
#     'npxG': 1.96551,
#     'npxGA': 0.795292,
#     'ppda': {'att': 193, 'def': 22},
#     'ppda_allowed': {'att': 224, 'def': 18},
#     'deep': 5,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 2.3402000000000003,
#     'result': 'd',
#     'date': '2021-11-07 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 1.1702180000000002},
#    {'h_a': 'a',
#     'xG': 1.46689,
#     'xGA': 2.31744,
#     'npxG': 1.46689,
#     'npxGA': 2.31744,
#     'ppda': {'att': 230, 'def': 31},
#     'ppda_allowed': {'att': 307, 'def': 32},
#     'deep': 5,
#     'deep_allowed': 8,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 0.7541,
#     'result': 'l',
#     'date': '2021-11-21 16:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.8505499999999999},
#    {'h_a': 'a',
#     'xG': 0.864829,
#     'xGA': 1.90498,
#     'npxG': 0.864829,
#     'npxGA': 1.90498,
#     'ppda': {'att': 253, 'def': 37},
#     'ppda_allowed': {'att': 194, 'def': 21},
#     'deep': 6,
#     'deep_allowed': 13,
#     'scored': 0,
#     'missed': 0,
#     'xpts': 0.6196999999999999,
#     'result': 'd',
#     'date': '2021-11-27 17:30:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -1.0401509999999998},
#    {'h_a': 'h',
#     'xG': 1.9818,
#     'xGA': 0.707328,
#     'npxG': 1.22063,
#     'npxGA': 0.707328,
#     'ppda': {'att': 146, 'def': 38},
#     'ppda_allowed': {'att': 278, 'def': 22},
#     'deep': 5,
#     'deep_allowed': 4,
#     'scored': 1,
#     'missed': 0,
#     'xpts': 2.4334000000000002,
#     'result': 'w',
#     'date': '2021-11-30 20:15:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 0.5133020000000001},
#    {'h_a': 'h',
#     'xG': 1.41896,
#     'xGA': 1.19959,
#     'npxG': 1.41896,
#     'npxGA': 1.19959,
#     'ppda': {'att': 134, 'def': 28},
#     'ppda_allowed': {'att': 255, 'def': 23},
#     'deep': 7,
#     'deep_allowed': 5,
#     'scored': 2,
#     'missed': 2,
#     'xpts': 1.5383,
#     'result': 'd',
#     'date': '2021-12-05 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 0.21937000000000006},
#    {'h_a': 'a',
#     'xG': 1.72934,
#     'xGA': 2.74844,
#     'npxG': 0.968172,
#     'npxGA': 1.2261,
#     'ppda': {'att': 211, 'def': 18},
#     'ppda_allowed': {'att': 161, 'def': 23},
#     'deep': 1,
#     'deep_allowed': 8,
#     'scored': 2,
#     'missed': 3,
#     'xpts': 0.6751,
#     'result': 'l',
#     'date': '2021-12-11 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.25792799999999994},
#    {'h_a': 'a',
#     'xG': 0.227498,
#     'xGA': 3.31349,
#     'npxG': 0.227498,
#     'npxGA': 3.31349,
#     'ppda': {'att': 351, 'def': 13},
#     'ppda_allowed': {'att': 233, 'def': 20},
#     'deep': 2,
#     'deep_allowed': 14,
#     'scored': 0,
#     'missed': 7,
#     'xpts': 0.04529999999999999,
#     'result': 'l',
#     'date': '2021-12-14 20:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -3.0859919999999996},
#    {'h_a': 'h',
#     'xG': 1.31408,
#     'xGA': 3.69008,
#     'npxG': 0.55291,
#     'npxGA': 3.69008,
#     'ppda': {'att': 226, 'def': 16},
#     'ppda_allowed': {'att': 232, 'def': 31},
#     'deep': 7,
#     'deep_allowed': 14,
#     'scored': 1,
#     'missed': 4,
#     'xpts': 0.2098,
#     'result': 'l',
#     'date': '2021-12-18 17:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -3.1371700000000002},
#    {'h_a': 'h',
#     'xG': 2.04186,
#     'xGA': 0.960493,
#     'npxG': 2.04186,
#     'npxGA': 0.960493,
#     'ppda': {'att': 111, 'def': 18},
#     'ppda_allowed': {'att': 181, 'def': 21},
#     'deep': 8,
#     'deep_allowed': 2,
#     'scored': 3,
#     'missed': 1,
#     'xpts': 2.1539,
#     'result': 'w',
#     'date': '2022-01-02 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 1.0813669999999997},
#    {'h_a': 'a',
#     'xG': 2.26884,
#     'xGA': 2.3549,
#     'npxG': 2.26884,
#     'npxGA': 2.3549,
#     'ppda': {'att': 169, 'def': 20},
#     'ppda_allowed': {'att': 234, 'def': 25},
#     'deep': 6,
#     'deep_allowed': 9,
#     'scored': 3,
#     'missed': 2,
#     'xpts': 1.3017999999999998,
#     'result': 'w',
#     'date': '2022-01-16 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.08606000000000025},
#    {'h_a': 'h',
#     'xG': 1.12992,
#     'xGA': 1.15904,
#     'npxG': 1.12992,
#     'npxGA': 1.15904,
#     'ppda': {'att': 116, 'def': 19},
#     'ppda_allowed': {'att': 251, 'def': 19},
#     'deep': 11,
#     'deep_allowed': 9,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 1.3423,
#     'result': 'l',
#     'date': '2022-01-22 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.029120000000000035},
#    {'h_a': 'a',
#     'xG': 2.52914,
#     'xGA': 1.5013,
#     'npxG': 2.52914,
#     'npxGA': 1.5013,
#     'ppda': {'att': 148, 'def': 15},
#     'ppda_allowed': {'att': 291, 'def': 21},
#     'deep': 8,
#     'deep_allowed': 2,
#     'scored': 3,
#     'missed': 3,
#     'xpts': 2.1414,
#     'result': 'd',
#     'date': '2022-02-09 20:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': 1.0278399999999999},
#    {'h_a': 'a',
#     'xG': 0.242668,
#     'xGA': 2.58561,
#     'npxG': 0.242668,
#     'npxGA': 2.58561,
#     'ppda': {'att': 139, 'def': 23},
#     'ppda_allowed': {'att': 301, 'def': 27},
#     'deep': 4,
#     'deep_allowed': 10,
#     'scored': 0,
#     'missed': 3,
#     'xpts': 0.0782,
#     'result': 'l',
#     'date': '2022-02-12 15:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -2.342942},
#    {'h_a': 'h',
#     'xG': 1.74476,
#     'xGA': 2.60999,
#     'npxG': 1.74476,
#     'npxGA': 2.60999,
#     'ppda': {'att': 154, 'def': 30},
#     'ppda_allowed': {'att': 241, 'def': 29},
#     'deep': 6,
#     'deep_allowed': 12,
#     'scored': 2,
#     'missed': 4,
#     'xpts': 0.8092,
#     'result': 'l',
#     'date': '2022-02-20 14:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.8652299999999997},
#    {'h_a': 'a',
#     'xG': 0.141547,
#     'xGA': 5.3303,
#     'npxG': 0.141547,
#     'npxGA': 3.80797,
#     'ppda': {'att': 435, 'def': 17},
#     'ppda_allowed': {'att': 248, 'def': 22},
#     'deep': 3,
#     'deep_allowed': 13,
#     'scored': 0,
#     'missed': 6,
#     'xpts': 0.0015,
#     'result': 'l',
#     'date': '2022-02-23 19:45:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -3.666423},
#    {'h_a': 'h',
#     'xG': 1.89569,
#     'xGA': 2.47025,
#     'npxG': 1.89569,
#     'npxGA': 2.47025,
#     'ppda': {'att': 294, 'def': 37},
#     'ppda_allowed': {'att': 215, 'def': 12},
#     'deep': 16,
#     'deep_allowed': 10,
#     'scored': 0,
#     'missed': 4,
#     'xpts': 1.0085,
#     'result': 'l',
#     'date': '2022-02-26 12:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.57456},
#    {'h_a': 'a',
#     'xG': 2.14389,
#     'xGA': 0.359129,
#     'npxG': 2.14389,
#     'npxGA': 0.359129,
#     'ppda': {'att': 269, 'def': 24},
#     'ppda_allowed': {'att': 244, 'def': 21},
#     'deep': 12,
#     'deep_allowed': 6,
#     'scored': 0,
#     'missed': 1,
#     'xpts': 2.6335,
#     'result': 'l',
#     'date': '2022-03-05 12:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': 1.7847609999999998},
#    {'h_a': 'h',
#     'xG': 0.194028,
#     'xGA': 1.2729,
#     'npxG': 0.194028,
#     'npxGA': 1.2729,
#     'ppda': {'att': 229, 'def': 35},
#     'ppda_allowed': {'att': 237, 'def': 20},
#     'deep': 1,
#     'deep_allowed': 8,
#     'scored': 0,
#     'missed': 3,
#     'xpts': 0.4279,
#     'result': 'l',
#     'date': '2022-03-10 19:45:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.0788719999999998},
#    {'h_a': 'h',
#     'xG': 3.11755,
#     'xGA': 1.40148,
#     'npxG': 3.11755,
#     'npxGA': 1.40148,
#     'ppda': {'att': 200, 'def': 36},
#     'ppda_allowed': {'att': 212, 'def': 18},
#     'deep': 10,
#     'deep_allowed': 12,
#     'scored': 2,
#     'missed': 1,
#     'xpts': 2.5278,
#     'result': 'w',
#     'date': '2022-03-13 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 1.71607},
#    {'h_a': 'a',
#     'xG': 2.82103,
#     'xGA': 1.24075,
#     'npxG': 2.82103,
#     'npxGA': 1.24075,
#     'ppda': {'att': 251, 'def': 30},
#     'ppda_allowed': {'att': 272, 'def': 20},
#     'deep': 6,
#     'deep_allowed': 8,
#     'scored': 3,
#     'missed': 2,
#     'xpts': 2.4144,
#     'result': 'w',
#     'date': '2022-03-18 20:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': 1.58028},
#    {'h_a': 'h',
#     'xG': 1.50715,
#     'xGA': 2.06387,
#     'npxG': 1.50715,
#     'npxGA': 2.06387,
#     'ppda': {'att': 136, 'def': 21},
#     'ppda_allowed': {'att': 258, 'def': 13},
#     'deep': 18,
#     'deep_allowed': 11,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 0.9089,
#     'result': 'd',
#     'date': '2022-04-02 14:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.5567200000000001},
#    {'h_a': 'a',
#     'xG': 0.895612,
#     'xGA': 1.07422,
#     'npxG': 0.895612,
#     'npxGA': 1.07422,
#     'ppda': {'att': 171, 'def': 38},
#     'ppda_allowed': {'att': 192, 'def': 28},
#     'deep': 2,
#     'deep_allowed': 2,
#     'scored': 3,
#     'missed': 0,
#     'xpts': 1.1109,
#     'result': 'w',
#     'date': '2022-04-09 14:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.178608},
#    {'h_a': 'a',
#     'xG': 0.374044,
#     'xGA': 1.61656,
#     'npxG': 0.374044,
#     'npxGA': 1.61656,
#     'ppda': {'att': 251, 'def': 41},
#     'ppda_allowed': {'att': 197, 'def': 35},
#     'deep': 3,
#     'deep_allowed': 7,
#     'scored': 0,
#     'missed': 0,
#     'xpts': 0.3964,
#     'result': 'd',
#     'date': '2022-04-25 19:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -1.242516},
#    {'h_a': 'h',
#     'xG': 1.03608,
#     'xGA': 3.01431,
#     'npxG': 1.03608,
#     'npxGA': 3.01431,
#     'ppda': {'att': 374, 'def': 16},
#     'ppda_allowed': {'att': 264, 'def': 16},
#     'deep': 3,
#     'deep_allowed': 12,
#     'scored': 0,
#     'missed': 4,
#     'xpts': 0.3008,
#     'result': 'l',
#     'date': '2022-04-30 16:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -1.9782300000000002},
#    {'h_a': 'a',
#     'xG': 0.696785,
#     'xGA': 2.7227,
#     'npxG': 0.696785,
#     'npxGA': 2.7227,
#     'ppda': {'att': 306, 'def': 15},
#     'ppda_allowed': {'att': 247, 'def': 28},
#     'deep': 3,
#     'deep_allowed': 14,
#     'scored': 1,
#     'missed': 2,
#     'xpts': 0.2201,
#     'result': 'l',
#     'date': '2022-05-08 13:00:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -2.0259150000000004},
#    {'h_a': 'h',
#     'xG': 0.499789,
#     'xGA': 1.46853,
#     'npxG': 0.499789,
#     'npxGA': 1.46853,
#     'ppda': {'att': 491, 'def': 23},
#     'ppda_allowed': {'att': 256, 'def': 26},
#     'deep': 0,
#     'deep_allowed': 9,
#     'scored': 0,
#     'missed': 3,
#     'xpts': 0.6066,
#     'result': 'l',
#     'date': '2022-05-11 18:30:00',
#     'wins': 0,
#     'draws': 0,
#     'loses': 1,
#     'pts': 0,
#     'npxGD': -0.9687409999999999},
#    {'h_a': 'h',
#     'xG': 2.22282,
#     'xGA': 2.25898,
#     'npxG': 2.22282,
#     'npxGA': 2.25898,
#     'ppda': {'att': 169, 'def': 25},
#     'ppda_allowed': {'att': 195, 'def': 14},
#     'deep': 10,
#     'deep_allowed': 12,
#     'scored': 1,
#     'missed': 1,
#     'xpts': 1.3639000000000001,
#     'result': 'd',
#     'date': '2022-05-15 13:00:00',
#     'wins': 0,
#     'draws': 1,
#     'loses': 0,
#     'pts': 1,
#     'npxGD': -0.03616000000000019},
#    {'h_a': 'a',
#     'xG': 1.47786,
#     'xGA': 0.844985,
#     'npxG': 0.716686,
#     'npxGA': 0.844985,
#     'ppda': {'att': 262, 'def': 20},
#     'ppda_allowed': {'att': 206, 'def': 21},
#     'deep': 4,
#     'deep_allowed': 4,
#     'scored': 2,
#     'missed': 1,
#     'xpts': 1.9476,
#     'result': 'w',
#     'date': '2022-05-22 15:00:00',
#     'wins': 1,
#     'draws': 0,
#     'loses': 0,
#     'pts': 3,
#     'npxGD': -0.12829899999999994}]}}
